# %% [markdown]
# <a href="https://colab.research.google.com/github/SoumyadeepDebnath/Data-Engineering-using-Python/blob/main/6.%20Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas library provides high-performance, easy-to-use data structures and data analysis tools in Python.**

# %%
# pip install pandas or conda install pandas - for manually install
import pandas as pd #Import Pandas

# %%
#default read with comma separated values
#first row will be considered as header
#new index column will be generated 0 to n-1 rows
df = pd.read_csv('/content/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0            892         0       3  ...    7.8292   NaN         Q
# 1            893         1       3  ...    7.0000   NaN         S
# 2            894         0       2  ...    9.6875   NaN         Q
# 3            895         0       3  ...    8.6625   NaN         S
# 4            896         1       3  ...   12.2875   NaN         S
# ..           ...       ...     ...  ...       ...   ...       ...
# 413         1305         0       3  ...    8.0500   NaN         S
# 414         1306         1       1  ...  108.9000  C105         C
# 415         1307         0       3  ...    7.2500   NaN         S
# 416         1308         0       3  ...    8.0500   NaN         S
# 417         1309         0       3  ...   22.3583   NaN         C
#
# [418 rows x 12 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ##### **Pickle**

# %% [markdown]
# ```
# The 'pickle' module implements binary protocols for serializing and de-serializing a Python object structure.
# Pickling is the process whereby a Python object hierarchy is converted into a byte stream, and unpickling is the inverse operation, whereby a byte stream (from a binary file or bytes-like object) is converted back into an object hierarchy.
# Pickling (and unpickling) is alternatively known as serialization, marshalling or flattening.
# ```

# %%
df.to_pickle("my_pickle_file") #convet into serializable bytecode for encryption, can't open the file without code

# %%
h5_data = pd.HDFStore('test.h5')
h5_data['obj1'] = df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#!pip install --upgrade tables #only once required
# Out:
# ...
#      |████████████████████████████████| 5.9 MB 10.2 MB/s
# ...
#   Attempting uninstall: tables
#     Found existing installation: tables 3.4.4
#     Uninstalling tables-3.4.4:
#       Successfully uninstalled tables-3.4.4
# ...

# %%
print(h5_data['obj1'])
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0            892         0       3  ...    7.8292   NaN         Q
# 1            893         1       3  ...    7.0000   NaN         S
# 2            894         0       2  ...    9.6875   NaN         Q
# 3            895         0       3  ...    8.6625   NaN         S
# 4            896         1       3  ...   12.2875   NaN         S
# ..           ...       ...     ...  ...       ...   ...       ...
# 413         1305         0       3  ...    8.0500   NaN         S
# 414         1306         1       1  ...  108.9000  C105         C
# 415         1307         0       3  ...    7.2500   NaN         S
# 416         1308         0       3  ...    8.0500   NaN         S
# 417         1309         0       3  ...   22.3583   NaN         C
#
# [418 rows x 12 columns]

# %% [markdown]
# ##### **Convert dataframe to csv**

# %%
df1  =  df.head()
df1
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0          892         0       3  ...   7.8292   NaN         Q
# 1          893         1       3  ...   7.0000   NaN         S
# 2          894         0       2  ...   9.6875   NaN         Q
# 3          895         0       3  ...   8.6625   NaN         S
# 4          896         1       3  ...  12.2875   NaN         S
#
# [5 rows x 12 columns]

# %%
df1.to_csv("test1.csv") #new column added - index - with no header
pd.read_csv('test1.csv')
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  ...   Ticket     Fare  Cabin  Embarked
# 0           0          892         0       3  ...   330911   7.8292    NaN         Q
# 1           1          893         1       3  ...   363272   7.0000    NaN         S
# 2           2          894         0       2  ...   240276   9.6875    NaN         Q
# 3           3          895         0       3  ...   315154   8.6625    NaN         S
# 4           4          896         1       3  ...  3101298  12.2875    NaN         S
#
# [5 rows x 13 columns]

# %%
df1.to_csv("test2.csv",index=False) #no new column added 
pd.read_csv('test2.csv')
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0          892         0       3  ...   7.8292   NaN         Q
# 1          893         1       3  ...   7.0000   NaN         S
# 2          894         0       2  ...   9.6875   NaN         Q
# 3          895         0       3  ...   8.6625   NaN         S
# 4          896         1       3  ...  12.2875   NaN         S
#
# [5 rows x 12 columns]

# %%
#with no column and specific separator (;) - for storing only data in different csv
df1.to_csv("test3.csv",index=False,header=False,sep = ";")
pd.read_csv('test3.csv')
# Out:
#       892;0;3;Kelly           Mr. James;male;34.5;0;0;330911;7.8292;;Q
# 0    893;1;3;Wilkes   Mrs. James (Ellen Needs);female;47.0;1;0;3632...
# 1     894;0;2;Myles   Mr. Thomas Francis;male;62.0;0;0;240276;9.687...
# 2      895;0;3;Wirz          Mr. Albert;male;27.0;0;0;315154;8.6625;;S
# 3  896;1;3;Hirvonen   Mrs. Alexander (Helga E Lindqvist);female;22....

# %% [markdown]
# ##### **Replaced comma (,) by hashtag (#) in the file. Now read.**

# %%
#read with specific separator - sep=''
#specific column names - names[]
#no header - header=None
#remove specific rows - skiprows[] - if header exists (header = 0) and n-1 for nth row in the file, otherwise n for nth row in the file
columnNames = ['a','b','c','d','e','f','g','h','i','j','k','l']
uselessRows = [0,2,4,6]
df = pd.read_csv('/content/titanic.csv',sep='#',header=None,names=columnNames,skiprows=uselessRows)

# %%
df
# Out:
#         a  b  c  ...         j     k  l
# 0     892  0  3  ...    7.8292   NaN  Q
# 1     894  0  2  ...    9.6875   NaN  Q
# 2     896  1  3  ...   12.2875   NaN  S
# 3     898  1  3  ...    7.6292   NaN  Q
# 4     899  0  2  ...   29.0000   NaN  S
# ..    ... .. ..  ...       ...   ... ..
# 410  1305  0  3  ...    8.0500   NaN  S
# 411  1306  1  1  ...  108.9000  C105  C
# 412  1307  0  3  ...    7.2500   NaN  S
# 413  1308  0  3  ...    8.0500   NaN  S
# 414  1309  0  3  ...   22.3583   NaN  C
#
# [415 rows x 12 columns]

# %%
#specific values will be replaced by NaN - na_values[]
df = pd.read_csv('/content/titanic.csv',sep='#',na_values=['male'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0            892         0       3  ...    7.8292   NaN         Q
# 1            893         1       3  ...    7.0000   NaN         S
# 2            894         0       2  ...    9.6875   NaN         Q
# 3            895         0       3  ...    8.6625   NaN         S
# 4            896         1       3  ...   12.2875   NaN         S
# ..           ...       ...     ...  ...       ...   ...       ...
# 413         1305         0       3  ...    8.0500   NaN         S
# 414         1306         1       1  ...  108.9000  C105         C
# 415         1307         0       3  ...    7.2500   NaN         S
# 416         1308         0       3  ...    8.0500   NaN         S
# 417         1309         0       3  ...   22.3583   NaN         C
#
# [418 rows x 12 columns]

# %%
#remove specific rows - skiprows[] - n-1 for nth row in the file
df1 = pd.read_csv('/content/titanic.csv',sep=',',skiprows=[1,2])

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0            894         0       2  ...    9.6875   NaN         Q
# 1            895         0       3  ...    8.6625   NaN         S
# 2            896         1       3  ...   12.2875   NaN         S
# 3            897         0       3  ...    9.2250   NaN         S
# 4            898         1       3  ...    7.6292   NaN         Q
# ..           ...       ...     ...  ...       ...   ...       ...
# 411         1305         0       3  ...    8.0500   NaN         S
# 412         1306         1       1  ...  108.9000  C105         C
# 413         1307         0       3  ...    7.2500   NaN         S
# 414         1308         0       3  ...    8.0500   NaN         S
# 415         1309         0       3  ...   22.3583   NaN         C
#
# [416 rows x 12 columns]

# %% [markdown]
# ##### **Dataframe definations**

# %%
df = pd.read_csv('/content/titanic.csv',sep=',')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0            892         0       3  ...    7.8292   NaN         Q
# 1            893         1       3  ...    7.0000   NaN         S
# 2            894         0       2  ...    9.6875   NaN         Q
# 3            895         0       3  ...    8.6625   NaN         S
# 4            896         1       3  ...   12.2875   NaN         S
# ..           ...       ...     ...  ...       ...   ...       ...
# 413         1305         0       3  ...    8.0500   NaN         S
# 414         1306         1       1  ...  108.9000  C105         C
# 415         1307         0       3  ...    7.2500   NaN         S
# 416         1308         0       3  ...    8.0500   NaN         S
# 417         1309         0       3  ...   22.3583   NaN         C
#
# [418 rows x 12 columns]

# %%
df.shape #returns tuple (row,column)
# Out:
# (418, 12)

# %%
row,column = df.shape
print("Row - ",row,"\nColumn - ",column)
# Out:
# Row -  418
# Column -  12

# %%
df.size #returns total elements = row*column
# Out:
# 5016

# %%
df.columns #return column names
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes #datatypes of all columns
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# For any column *(total data = length)* **after sort**, <br>
# > 0th percentile (min) = oth index, <br>
# > 100th percentile (max) = (length-1)*th index <br>
# > 25th, 50th, 75th percentile = *(length/4)*th, *(length/2)*th, *(3×length/4)*th indeces respectively

# %%
df.describe() #describe all numerical columns (not categorical - pandas object means string)
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   418.000000  418.000000  418.000000  ...  418.000000  418.000000  417.000000
# mean   1100.500000    0.363636    2.265550  ...    0.447368    0.392344   35.627188
# std     120.810458    0.481622    0.841838  ...    0.896760    0.981429   55.907576
# min     892.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     996.250000    0.000000    1.000000  ...    0.000000    0.000000    7.895800
# 50%    1100.500000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%    1204.750000    1.000000    3.000000  ...    1.000000    0.000000   31.500000
# max    1309.000000    1.000000    3.000000  ...    8.000000    9.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df.head() #default 5 rows from first
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0          892         0       3  ...   7.8292   NaN         Q
# 1          893         1       3  ...   7.0000   NaN         S
# 2          894         0       2  ...   9.6875   NaN         Q
# 3          895         0       3  ...   8.6625   NaN         S
# 4          896         1       3  ...  12.2875   NaN         S
#
# [5 rows x 12 columns]

# %%
df.tail() #default 5 rows from last
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 413         1305         0       3  ...    8.0500   NaN         S
# 414         1306         1       1  ...  108.9000  C105         C
# 415         1307         0       3  ...    7.2500   NaN         S
# 416         1308         0       3  ...    8.0500   NaN         S
# 417         1309         0       3  ...   22.3583   NaN         C
#
# [5 rows x 12 columns]

# %%
df['PassengerId']
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %%
type(df['PassengerId'])
# Out:
# pandas.core.series.Series

# %%
df[['PassengerId']]
# Out:
#      PassengerId
# 0            892
# 1            893
# 2            894
# 3            895
# 4            896
# ..           ...
# 413         1305
# 414         1306
# 415         1307
# 416         1308
# 417         1309
#
# [418 rows x 1 columns]

# %%
type(df[['PassengerId']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['PassengerId','Age']]
# Out:
#      PassengerId   Age
# 0            892  34.5
# 1            893  47.0
# 2            894  62.0
# 3            895  27.0
# 4            896  22.0
# ..           ...   ...
# 413         1305   NaN
# 414         1306  39.0
# 415         1307  38.5
# 416         1308   NaN
# 417         1309   NaN
#
# [418 rows x 2 columns]

# %% [markdown]
# ##### **Other Inputs**

# %% [markdown]
# Input from excel with specific sheet

# %%
dfExcel = pd.read_excel('/content/LUSID Excel-Business Agility-MakingSimpleChangesQuicklyAndEasily.xlsx',sheet_name='Create your instrument universe')

# %% [markdown]
# Input from website

# %%
dfHtml = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
type(dfHtml)
# Out:
# list

# %%
len(dfHtml)
# Out:
# 6

# %%
dfHtml[0]
# Out:
#        Season  ...                                    PTS
# 0     2008-09  ...  Did Not Play (other pro league—Spain)
# 1     2009-10  ...                                    6.3
# 2     2010-11  ...                                    9.9
# 3     2011-12  ...                                    9.1
# 4     2012-13  ...                                   13.2
# 5     2013-14  ...                                   15.1
# 6     2014-15  ...                                   14.3
# 7     2015-16  ...                                   12.6
# 8     2016-17  ...                                   14.8
# 9     2016-17  ...                                   15.1
# 10    2016-17  ...                                   14.2
# 11    2017-18  ...                                   12.6
# 12    2018-19  ...                                   15.0
# 13    2019-20  ...                                   15.4
# 14    2020-21  ...                                   11.1
# ...

# %%
for i in range(len(dfHtml)): #create each csv from the site
    dfHtml[i].to_csv(f"html_data{i}.csv", index=False)

# %% [markdown]
# Read csv from Github Raw data

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ##### **JSON Input**

# %%
import json

# %%
s = """{
"name" :"sudh",
"phone_no" : 45454545,
"company":["iNeuron", "EY" , "unilver" , "verizon" , "deloitte" , "wipro"]
}
"""

# %% [markdown]
# JSON to dataframe

# %%
s1 = json.loads(s)

# %%
s1
# Out:
# {'company': ['iNeuron', 'EY', 'unilver', 'verizon', 'deloitte', 'wipro'],
#  'name': 'sudh',
#  'phone_no': 45454545}

# %%
pd.DataFrame(s1)
# Out:
#    name  phone_no   company
# 0  sudh  45454545   iNeuron
# 1  sudh  45454545        EY
# 2  sudh  45454545   unilver
# 3  sudh  45454545   verizon
# 4  sudh  45454545  deloitte
# 5  sudh  45454545     wipro

# %%
df = pd.DataFrame(s1,columns=['comp'])
df
# Out:
# Empty DataFrame
# Columns: [comp]
# Index: []

# %%
import requests

# %%
res = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
res
# Out:
# <Response [200]>

# %%
js = res.json()

# %%
js
# Out:
# [{'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'MEMBER',
#   'body': '- [x] closes #45231\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n\r\nConfirmed this issue did not exist on 1.3.x, so no whatsnew entry necessary.',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45274/comments',
#   'created_at': '2022-01-08T20:15:14Z',
#   'draft': False,
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45274/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/45274',
#   'id': 1097026326,
#   'labels': [],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45274/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'PR_kwDOAA0YD84wsTCE',
# ...

# %%
js[0]['title']
# Out:
# 'Fix groupby any/all on an empty series/frame'

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# Fix groupby any/all on an empty series/frame
# BUG: can_hold_element size checks on ints/floats
# BUG: DataFrame.astype preserve subclasses GH#40810
# BUG: In Series all null-values are printed as NaN
# DOC: improving example
# PERF: 1.4.0rc1 Execution time of pd.read_sql increased from seconds to minutes
# ENH: Allow `df.to_sql()` to pass dialect kwargs to SQLAlchemy.
# CI: Simplify GHA dependency files
# ENH: Index[complex]
# BUG/PERF: MaskedArray.searchsorted(np.nan)
# ENH: Bring over Microsoft typing stubs as starting point for typing public API
# ENH: Add set of tests to type check the public APIs
# DOC CLN: use ``color`` shared doc string
# BUG: Unexpected behavioral change, NaN support dropped with `dispatch_ufunc_with_out`
# BUG: `DataFrame.groupby` silently ignores `as_index=False` when aggregating with multiple functions on a single column
# TYP: Add types for excel writer classes
# API: Consistency between DataFrame, MultiIndex.to_frame and reset_index
# ...

# %%
len(js)
# Out:
# 30

# %%
js
# Out:
# [{'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'MEMBER',
#   'body': '- [x] closes #45231\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n\r\nConfirmed this issue did not exist on 1.3.x, so no whatsnew entry necessary.',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45274/comments',
#   'created_at': '2022-01-08T20:15:14Z',
#   'draft': False,
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45274/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/45274',
#   'id': 1097026326,
#   'labels': [],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45274/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'PR_kwDOAA0YD84wsTCE',
# ...

# %%
df4 = pd.DataFrame(js)

# %%
df4.to_csv('json_dump.csv')

# %%
js[0]['user']
# Out:
# {'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#  'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#  'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#  'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#  'gravatar_id': '',
#  'html_url': 'https://github.com/rhshadrach',
#  'id': 45562402,
#  'login': 'rhshadrach',
#  'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#  'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#  'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#  'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#  'site_admin': False,
#  'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#  'type': 'User',
# ...

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  ... performed_via_github_app
# 0   https://api.github.com/repos/pandas-dev/pandas...  ...                      NaN
# 1   https://api.github.com/repos/pandas-dev/pandas...  ...                      NaN
# 2   https://api.github.com/repos/pandas-dev/pandas...  ...                      NaN
# 3   https://api.github.com/repos/pandas-dev/pandas...  ...                      NaN
# 4   https://api.github.com/repos/pandas-dev/pandas...  ...                      NaN
# 5   https://api.github.com/repos/pandas-dev/pandas...  ...                      NaN
# 6   https://api.github.com/repos/pandas-dev/pandas...  ...                      NaN
# 7   https://api.github.com/repos/pandas-dev/pandas...  ...                      NaN
# 8   https://api.github.com/repos/pandas-dev/pandas...  ...                      NaN
# 9   https://api.github.com/repos/pandas-dev/pandas...  ...                      NaN
# ...

# %%
lis=[]
for i in range(len(js)):
    lis.append(js[i]['user'])
pd.DataFrame(lis)
# Out:
#                   login        id  ...  type site_admin
# 0            rhshadrach  45562402  ...  User      False
# 1          jbrockmendel   8078968  ...  User      False
# 2          jbrockmendel   8078968  ...  User      False
# 3               realead  17513912  ...  User      False
# 4               realead  17513912  ...  User      False
# 5             SimoneD89  40129272  ...  User      False
# 6                cansjt  54809532  ...  User      False
# 7             mroeschke  10647082  ...  User      False
# 8          jbrockmendel   8078968  ...  User      False
# 9          jbrockmendel   8078968  ...  User      False
# 10               Dr-Irv  15113894  ...  User      False
# 11               Dr-Irv  15113894  ...  User      False
# 12             attack68  24256554  ...  User      False
# 13   DamianBarabonkovQC  65635505  ...  User      False
# 14           Demetrio92  22682408  ...  User      False
# 15                phofl  61934744  ...  User      False
# ...

# %%
user = []
res=requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')
js=res.json()
for i in range(len(js)):
    user.append(js[i]['user'])

pd.DataFrame(user)
# Out:
#                   login        id  ...  type site_admin
# 0            rhshadrach  45562402  ...  User      False
# 1          jbrockmendel   8078968  ...  User      False
# 2          jbrockmendel   8078968  ...  User      False
# 3               realead  17513912  ...  User      False
# 4               realead  17513912  ...  User      False
# 5             SimoneD89  40129272  ...  User      False
# 6                cansjt  54809532  ...  User      False
# 7             mroeschke  10647082  ...  User      False
# 8          jbrockmendel   8078968  ...  User      False
# 9          jbrockmendel   8078968  ...  User      False
# 10               Dr-Irv  15113894  ...  User      False
# 11               Dr-Irv  15113894  ...  User      False
# 12             attack68  24256554  ...  User      False
# 13   DamianBarabonkovQC  65635505  ...  User      False
# 14           Demetrio92  22682408  ...  User      False
# 15                phofl  61934744  ...  User      False
# ...

# %%
pd.DataFrame([js[i]["user"] for i in range(len(js))])
# Out:
#                   login        id  ...  type site_admin
# 0            rhshadrach  45562402  ...  User      False
# 1          jbrockmendel   8078968  ...  User      False
# 2          jbrockmendel   8078968  ...  User      False
# 3               realead  17513912  ...  User      False
# 4               realead  17513912  ...  User      False
# 5             SimoneD89  40129272  ...  User      False
# 6                cansjt  54809532  ...  User      False
# 7             mroeschke  10647082  ...  User      False
# 8          jbrockmendel   8078968  ...  User      False
# 9          jbrockmendel   8078968  ...  User      False
# 10               Dr-Irv  15113894  ...  User      False
# 11               Dr-Irv  15113894  ...  User      False
# 12             attack68  24256554  ...  User      False
# 13   DamianBarabonkovQC  65635505  ...  User      False
# 14           Demetrio92  22682408  ...  User      False
# 15                phofl  61934744  ...  User      False
# ...

# %%
l = []
for i in range(len(js)):
    l.append(js[i]['user'])
    
pd.DataFrame(l)
# Out:
#                   login        id  ...  type site_admin
# 0            rhshadrach  45562402  ...  User      False
# 1          jbrockmendel   8078968  ...  User      False
# 2          jbrockmendel   8078968  ...  User      False
# 3               realead  17513912  ...  User      False
# 4               realead  17513912  ...  User      False
# 5             SimoneD89  40129272  ...  User      False
# 6                cansjt  54809532  ...  User      False
# 7             mroeschke  10647082  ...  User      False
# 8          jbrockmendel   8078968  ...  User      False
# 9          jbrockmendel   8078968  ...  User      False
# 10               Dr-Irv  15113894  ...  User      False
# 11               Dr-Irv  15113894  ...  User      False
# 12             attack68  24256554  ...  User      False
# 13   DamianBarabonkovQC  65635505  ...  User      False
# 14           Demetrio92  22682408  ...  User      False
# 15                phofl  61934744  ...  User      False
# ...

# %%
json_data = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
data = pd.DataFrame.from_records(json_data['user'])
data.head()
# Out:
#           login        id  ...  type site_admin
# 0    rhshadrach  45562402  ...  User      False
# 1  jbrockmendel   8078968  ...  User      False
# 2  jbrockmendel   8078968  ...  User      False
# 3       realead  17513912  ...  User      False
# 4       realead  17513912  ...  User      False
#
# [5 rows x 18 columns]
